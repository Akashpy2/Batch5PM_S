# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\DELL\\Batch_Feb23_5PM'

# %%
os.chdir('D:\Office\Python\Rk\PYTHON_master\samplefiles')

# %%
os.getcwd()
# Out:
# 'D:\\Office\\Python\\Rk\\PYTHON_master\\samplefiles'

# %%
f=open('date1920.txt')
print(f)
# Out:
# <_io.TextIOWrapper name='date1920.txt' mode='r' encoding='cp1252'>

# %%
f=open('date1920.txt','r')
print(f)
# Out:
# <_io.TextIOWrapper name='date1920.txt' mode='r' encoding='cp1252'>

# %%
f=open('date1920.txt','r')
print(f.readline())
# Out:
# abcdefgh

# %%
f=open('date1920.txt','r')
print(f.readlines())
# Out:
# ['abcdefgh\n', '123456\n', 'hello \n', 'world\n']

# %%
# read file content only specific length data
ft=open('date1920.txt','r')
ft.read(5)
# Out:
# 'abcde'

# %%
f=open('test1.txt','w')
r=f.write('Hello how r u')
f.close()
#print(r)

# %%
f=open('test1.txt','a')
r=f.write('good')
f.close()
#print(r)

# %%
f=open('Image1.jpg','rb')
print(f)
# Out:
# <_io.BufferedReader name='Image1.jpg'>

# %%
f=open('Image1.jpg','rb')
for i in f:
    print(i)
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00\x84\x00\n'
# ...

# %%
f=open('Image1.jpg','rb')
f1=open('Image2.jpg','wb')
for i in f:
    print(f1.write(i))
f.close()
f1.close()
# Out:
# 26
# 648
# 222
# 5
# 306
# 411
# 138
# 163
# 57
# 40
# 281
# 900
# 904
# 50
# 48
# 548
# 294
# 86
# 95
# 33
# 1121
# 405
# 514

# %%
with open('Image6_png.png', 'rb') as f:
    data = f.read()

# %%
with open('Image7_png.png', 'wb') as f:
    f.write(data)
